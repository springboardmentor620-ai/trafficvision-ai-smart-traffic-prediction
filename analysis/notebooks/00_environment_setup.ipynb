# %%
import pandas as pd
import numpy as np

print("TrafficVision AI Analysis Environment Ready ✅")
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
# Out:
# TrafficVision AI Analysis Environment Ready ✅
# Pandas: 3.0.3
# NumPy: 2.5.1
